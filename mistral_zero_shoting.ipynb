# %%
from datasets import *

data_path = 'exos_to_csv.csv'
dataset = load_dataset('csv', data_files=data_path)

# %%
# Split the dataset into 3 sets for train, test and validation
train_testsplit = dataset['train'].train_test_split(test_size=0.2)
test_validsplit = train_testsplit['test'].train_test_split(test_size=0.5)

# %%
ds = DatasetDict({
    'train': train_testsplit['train'],
    'test': test_validsplit['test'],
    'valid': test_validsplit['train']
})

# %%
ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['filename', 'text'],
#         num_rows: 1022
#     })
#     test: Dataset({
#         features: ['filename', 'text'],
#         num_rows: 128
#     })
#     valid: Dataset({
#         features: ['filename', 'text'],
#         num_rows: 128
#     })
# })

# %% [markdown]
# ## Load Mistral Model

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2")

# With left-padding
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2", padding_side="left")
# Out:
# /home/huang_h/.local/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# /home/huang_h/.local/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
tokenizer.pad_token = tokenizer.eos_token  # Most LLMs don't have a pad token by default

# %% [markdown]
# ### Using HuggingFace Pipeline Method for Text Generation Task

# %%
from transformers import pipeline
# Out:
# 2024-05-21 16:04:06.311193: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-21 16:04:06.311236: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-21 16:04:06.313060: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-05-21 16:04:06.321756: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-21 16:04:07.372017: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Iterate through the dataset
def data_iterator(corpus):
    for item in corpus["text"]:

        # Yield a chat-formatted message
        yield {
            "role": "user",
            "content": item
        }

        # formatted_message = tokenizer.apply_chat_template([message], add_generation_prompt=True, tokenize=False)

# %% [markdown]
# ### Generation Process

# %%
import torch

# %%
def get_generated_text(corpus, model, tokenizer):

    # Initialize the generator
    generator = pipeline(
        task='text-generation',
        model=model,
        tokenizer=tokenizer,
        torch_dtype=torch.bfloat16,
        device_map='auto',
        batch_size=2
    )

    # Get the generated text
    messages = data_iterator(corpus)
    generated_text = []

    for msg in messages:
        # Define a prompt
        prompt = f"Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from {msg['content']} and summarize the key themes. Based on the information, generate some semantically exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format and do not generate directly answers to these exercises. You can play the role of a teacher. ***Generated text***:"

        outputs = generator(
            prompt,
            max_new_tokens = 50,
            do_sample=True,
            temperature=0.5,
            top_k=50,
            top_p=0.95
        )

        generated_text.append(outputs[0]['generated_text'])

    return generated_text

# %%
consigne_generated = get_generated_text(ds["train"], model=model, tokenizer=tokenizer)

# %%
for sample in consigne_generated:
    print(sample)
    print(100 * "-")
# Out:
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie ces phrases et conjugue les verbes entre parenthèses au présent.
# a. Elle (prêter) sa voiture.
# b. Ils (annoncer) une bonne nouvelle.
# c. Tu (chercher) un ballon.
# d. J’ (admirer) le paysage.
# e. Nous (sauter) dans la piscine. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Il prête sa voiture.
# b. Ils annoncent une bonne nouvelle.
# c. Tu cherches un ballon.
# d. Je admire le paysage.
# e. Nous sautons
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie en choisissant le verbe être ou le verbe avoir au futur.
# a. elles (seront / sont) ➞ elles …
# b. j’ (ai / aurai) ➞ j’ …
# c. vous (aurez / avez) ➞ vous …
# d. tu (es / seras) ➞ tu …
# e. nous (serons / sommes) ➞ nous …
# f. il (a / aura) ➞ il … and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. elles seront
# b. j' aurai
# c. vous aurez
# d. tu seras
# e. nous serons
# f. il aura
#
# Exercise: Choose the correct verb in
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Retrouve les deux sens des mots en gras.
# addition ◆ courrier ◆ résultat ◆ caractère
# a. Je lui ai écrit une longue lettre.
# b. Connais-tu l’ordre des lettres sur un clavier ?
# c. Le serveur nous a apporté la note.
# d. Quelle est ta meilleure note en français ? and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Récupérez les deux sens des mots en gras.
# multiplication ◆ correspondance ◆ produit ◆ personne
# a. Nous avons multiplié les nombres.
# b. Quel
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie uniquement les phrases qui contiennent les verbes faire ou aller au futur.
# a. Demain matin, nous ferons une randonnée.
# b. Quand tu iras le voir, embrasse-le de ma part.
# c. À quelle heure allez-vous partir ?
# d. Je ferai mes devoirs après le goûter.
# e. Tu vas au cinéma.
# f. Le loup fera peur au Petit Chaperon rouge. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Demain matin, nous ferons une randonnée dans le parc.
# b. Quand tu iras à la bibliothèque, emprunte-moins livres pour moi.
# c. À
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Lis cet extrait du règlement du basket et complète-le avec les mots de la liste.
# joueur ◆ dribbler ◆ tirer ◆ ballon
# Un … qui est immobile quand il reçoit le … peut pivoter sur l’un ou l’autre pied.
# Un joueur qui est en mouvement quand il reçoit le ballon a le droit d’effectuer deux pas avant de s’arrêter, de passer le ballon ou bien de tirer en course.
# Il est interdit de … à deux mains.
# Il est interdit de reprendre un dribble qui a été arrêté.
# Dans ce cas, il faut passer, pivoter ou … . and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Joueur ◆ dribbleur ◆ passer ◆ ballon ◆ pivoter ◆ arrêter
# Un joueur qui est immobile quand il reçoit le ballon peut pivoter sur l
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Remplace le pronom personnel en gras par un groupe nominal de ton choix.
# a. Elle a perdu sa trousse.
# b. Il a vu le film trois fois.
# c. Nous faisons le chemin tous les jours.
# d. Ils ont des vélos tout neufs. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
#  a. Elle a perdu sa **sac à dos**.
#  b. Il a vu le film **trois fois**.
#  c. Nous **faisons le chemin tous les jours**.
#  d. Ils ont
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète les expressions avec le mot qui manque.
# main ◆ pied ◆ tête ◆ yeux
# a. hocher la …
# b. cligner des …
# c. tendre la …
# d. donner un coup de … and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Main ◆ Pied ◆ Tête ◆ Yeux
# a. hocher la main
# b. cligner des yeux
# c. tendre la tête
# d. donner un coup de pied
#
#
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Remets les syllabes dans l’ordre pour retrouver les noms d’animaux.
# pard gué ◆ ta o rie ◆ che au tru ◆ pan chim zé ◆ rou kan gou and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Rétablissez les syllabes dans leur bonne place pour retrouver les noms des fruits.
# ba nane ◆ pa pe rin ◆ ki ki wi ◆ pi tange ◆ rou
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Souligne le groupe nominal de chaque phrase.
# a. Il a perdu ses lunettes.
# b. Le jeune loup est allé danser.
# c. J’essuierai la vaisselle.
# d. Nous n’avons pas du tout aimé le film.
# e. Les enfants de mon frère arriveront demain.
# f. Les arbustes fleuris ont gelé.
# g. Le chat des voisins est rentré. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
#  a. Il a perdu ses lunettes. (He lost his glasses.)
#  Souligne les mots suivants : perdu, lunettes.
#  b. Le jeune loup est allé danser. (The young
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète les phrases par un nom propre et un nom commun.
# a. Mon … Jules habite rue … .
# b. La famille … déménage à … .
# c. Le … de Kilian s’appelle … .
# d. … est un célèbre … . and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Mon père Jules habite rue du Faubourg Montmartre.
# b. La famille Dupont déménage à New York.
# c. Le chien de Kilian s'appelle Max.
#
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète avec un pronom personnel qui convient.
# a. Veux-… de la glace à la vanille ou au chocolat ?
# b. Pouvez-… m’aider à grimper la colline ?
# c. Ils font ce qu’… peuvent.
# d. … ne veut rien entendre.
# e. … ne peux ni ne veux rien faire ! and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Veux-vous… de la glace à la vanille ou au chocolat?
# b. Peut-on… m’aider à monter la colline?
# c. Ils font ce qu’
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète les phrases avec l’auxiliaire être au présent.
# a. Obélix n’… pas tombé dans la marmite.
# b. Je … allée chercher le pain.
# c. …-elles venues vous rendre visite ?
# d. Vous … restés auprès de vos amis. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Obélix n’est pas tombé dans la marmite.
# b. Je suis allée chercher le pain.
# c. Elles ont-elles venus vous rendre visite?
# d
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie uniquement les verbes voir et dire conjugués au futur.
# vous verrez ◆ il voit ◆ elle verra ◆ tu disais ◆ nous dirons ◆ elles disent ◆ on voit ◆ il voyait ◆ ils voient ◆ vous dites ◆ vous direz ◆ on dira ◆ je verrai and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Exercez-vous uniquement sur les verbes voir et dire conjugués au futur.
# tu verras ◆ vous verrez ◆ il voit ◆ elle verra ◆ nous dir
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie les listes sans intrus.
# a. aventureux ◆ s’aventurer ◆ avent ◆ aventure
# b. verser ◆ versement ◆ versant ◆ déverser
# c. bain ◆ baignade ◆ baigner ◆ bagnole
# d. mont ◆ montagne ◆ montrer ◆ montagnard and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
#
# a. aventureux ◆ s'aventurer ◆ avent ◆ aventure
# (1) Les aventureux sont des gens qui aiment s'aventurer dans des endroits
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Écris les verbes au présent à la personne demandée.
# a. prendre, avoir ➞ 1 re pers. sing.
# b. rougir, finir ➞ 2 e pers. sing.
# c. faire, dire ➞ 3 e pers. sing.
# d. pouvoir ➞ 1 re pers. plur.
# e. parler, être ➞ 2 e pers. plur.
# f. vouloir, voir ➞ 3 e pers. plur. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Écris les verbes au passé composé à la personne demandée.
# a. manger, avoir ➞ 1 re pers. sing.
# b. rougir, finir ��
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Écris une phrase en respectant l’ordre des classes grammaticales indiquées.
# nom propre / verbe / déterminant / adjectif / nom commun and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Ecrire une phrase en respectant l'ordre des classes grammaticales suivant : article défini, adjectif, nom commun, verbe, nom propre.
# Article défini : Le
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Classe les mots dans le tableau.
# accent circonflexe
# accent aigu
# accent grave
# a. un élève ◆ où ◆ l’arrivée ◆ le mètre ◆ bientôt ◆ l’école ◆ une opération
# b. une chèvre ◆ la forêt ◆ un éléphant ◆ la différence ◆ la bête ◆ à and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# accent circonflexe
# accent aigu
# accent grave
# a. un élève ◆ dans ◆ sa classe ◆ la lecture ◆ d'un livre ◆ bientôt ◆ finit
#
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète chaque phrase avec un verbe de la liste conjugué à l’imparfait.
# aller ◆ voir ◆ faire ◆ dire
# a. Nous … régulièrement au cinéma jusqu’au jour où la salle a fermé.
# b. Je … mes devoirs quand tu es arrivé.
# c. Jusqu’à six ans, il … bien.
# d. Au Moyen Âge, les troubadours … des poèmes. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Complète chaque phrase avec un verbe de la liste conjugué à l'imparfait. aller ◆ voir ◆ faire ◆ dire
# a. Nous allions régulièrement au ciné
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Conjugue les verbes au présent.
# a. Les timides (rougir) comme des tomates.
# b. Nous (finir) plus tard.
# c. Je (pâlir) d’horreur.
# d. Le blanc ( jaunir) au soleil. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Conjugaison des verbes au présent simple actif:
# a. Les timides (rougissent) comme des tomates.
# b. Nous (terminons) plus tard.
# c. Je (blanch
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Écris les noms suivants au pluriel.
# un bal ◆ un festival ◆ le total ◆ l’éventail ◆ un rail ◆ un détail and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Écrire les noms suivants au féminin :
# un arbre ◆ une table ◆ un livre ◆ un chat ◆ un crayon ◆ un poisson
# Exercice de
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Dans chaque liste, quel mot n’est pas à sa place, dans l’ordre alphabétique ?
# • abricot – biberon – cerise – éventail − domino
# • aviron – avis – aviser – avocat – avion − avoine
# • largeur – larme – lasso – larve – lasagnes and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Dans chaque liste, quel mot n’est pas en accord avec la règle de declinaison?
# • chat – chats – chasse – cheval – chapeau
# • feu – feu
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète la terminaison des verbes conjugués au passé composé.
# a. Le lapin a bond… .
# b. Je n’ai jamais aim… nager.
# c. Les voleurs ont emport… les bijoux.
# d. Vous avez dorm… toute la nuit. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Complète la terminaison des verbes conjugués au passé composé.
# a. Le chien a abo….
# b. Elle n’a jamais mangé… de fraises.
# c.
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Trouve la réponse à ces devinettes.
# a. On y prend sa douche : la … .
# b. On y dort : la … .
# c. On y prépare les repas : la … . and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Trouve la réponse à ces devinettes.
# a. Dans la salle de bain : la douche.
# b. Dans la chambre : le lit.
# c. Dans la cuisine : la table
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Classe les formes verbales dans le tableau.
# nous
# vous
# voyez • disons • faites • prenons • allez • pouvez • voulons • voyons • dites • venez • prenez • pouvons • allons • venons • voulez • faisons and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Nous
# Vous
# Voisons • Disons • Faisons • Prendrons • Allons • Pouvons • Voulons • Voisons • Diremos • Direz • Faites • Pre
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Réécris les phrases avec le pronom indiqué.
# a. Elle ne voyait pas plus loin que le bout de son nez. (ils)
# b. Vous alliez trop vite dans le virage. (nous)
# c. Que faisais-tu hier ? (vous)
# d. Ils disaient la vérité. (on) and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Ils ne voyaient pas plus loin que le bout de leur nez.
# b. Nous allions trop vite dans le virage.
# c. Qu'aviez-vous fait hier?
# d
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie les mots dans lesquels la lettre c produit le son [k].
# a. un croissant • une citrouille • un cirque
# b. une couronne • l’océan • la cruche
# c. une sorcière • une classe • Christelle and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Recopie les mots dans lesquels la lettre g produit le son [g].
# a. un gâteau • une girafe • un grappe
# b. une grotte • la gare •
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Trouve les pronoms personnels qui peuvent remplacer les groupes nominaux suivants.
# a. les souris
# b. les crapauds
# c. une tortue
# d. une girafe et une lionne
# e. un éléphant
# f. Pierre, Paul,
# Samira and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Trouve les pronoms personnels qui peuvent remplacer les groupes nominaux suivants.
# a. les souris (they, mice)
# b. les crapauds (they, toads)
# c
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie chaque mot encadré.
# bouleverser approfondir
# sommet
# étoile
# a. Vedette de cinéma.
# b. Point le plus élevé d’une montagne.
# c. Mettre dans un grand désordre.
# d. Réunion entre chefs d’État de plusieurs pays.
# e. Causer une vive émotion.
# f. Étudier en détail.
# g. Rendre plus profond.
# h. Astre qui brille dans le ciel. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Récite chaque mot encadré.
# bouleverser approfondir
# sommet
# étoile
# a. Étoile de cinéma.
# b. Point le plus haut d’une mont
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Écris un nom de la même famille que chaque verbe.
# a. retarder ➞ …
# d. respecter ➞ …
# b. refuser ➞ …
# e. camper ➞ …
# c. ajouter ➞ …
# f. acheter ➞ … and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
#
# a. ralentir ➞ Nom d'une personne ou d'un objet qui ralentit.
# d. respecter ➞ Nom d'une personne ou d'un objet qui
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Classe en deux colonnes les groupes nominaux selon leur nombre : singulier ou pluriel.
# a. une montagne haute
# b. des sommets enneigés
# c. des alpinistes courageuses
# d. plusieurs profonds ravins
# e. un soleil radieux
# f. cette terrible avalanche
# g. notre skieur national and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
#
# Analysez les textes suivants en deux colonnes les groupes nominaux selon leur nombre : singulier ou pluriel.
#
# a. une montagne élevée
# b. des sommets neige
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Écris les groupes nominaux soulignés au pluriel.
# a. Lucas met sa raquette et une serviette dans son sac de sport.
# b. Ce singe fait une grimace.
# c. Il a gagné le livre et une figurine de Batman.
# d. Les oiseaux migrateurs ont commencé leur voyage vers ce pays.
# e. Elles rangent cette boîte sur l’étagère. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Écris les groupes nominaux soulignés au féminin au pluriel.
# a. Elles mettent leur sac à dos et leurs lunettes dans la voiture.
# b. Ces fleurs
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Réécris les phrases en remplaçant je par tu.
# a. Je dirai bonjour à Lény.
# b. Je prendrai encore du dessert.
# c. Je pourrai venir ce soir.
# d. J’irai dormir chez Mado.
# e. Je ferai un gâteau au chocolat.
# f. Je verrai Alya et Théo au judo. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Tu diras bonjour à Lény.
# b. Tu prendras encore du dessert.
# c. Tu pourras venir ce soir.
# d. Tu iras dormir chez Mado.
# e.
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Replace les phrases dans l’ordre pour écrire un dialogue.
# a. Ça doit être intéressant, comme travail !
# b. Vous êtes dresseur d’animaux ?
# c. Oui, très intéressant.
# d. C’est mon métier, en effet. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Ça doit être agréable, pour être jardinier!
# b. Vous êtes agriculteur?
# c. Oui, très agréable.
# d. C'est mon
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie chaque liste sans l’intrus.
# a. partout ◆ grandes ◆ aussi ◆ demain
# b. tôt ◆ longtemps ◆ dormir ◆ assez
# c. espadrille ◆ pour ◆ de ◆ par
# d. car ◆ donc ◆ mais ◆ suivant and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. partout ◆ des ◆ petits ◆ ce soir
# b. tard ◆ peu ◆ se réveiller ◆ chaque jour
# c. chaussette ◆ pour ◆ de ◆
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Réécris ce texte en mettant les verbes en gras au futur.
# Enfin il peut faire ce qui lui plaît en sortant de l’école.
# Ce qu’il préfère, c’est jouer au football.
# Mais il est tout seul.
# Les autres ne viennent au stade que lorsqu’ils ont terminé leurs devoirs.
# Paul s’allonge dans l’herbe et regarde le ciel.
# Paul s’ennuie.
# Hans Joachim Schädlich,
# Le Coupeur de mots, trad.
# J.
# Etoré et B.
# Lortholary, © Flammarion, coll. « Castor Poche » and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Enfin, il pourra faire ce qu'il veut en sortant de l'école.
# Ce qu'il préfère, c'est jouer au football.
# Mais il sera seul.
#
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie les phrases en remplaçant le pronom sujet par on quand c’est possible.
# a. Il commande une soupe.
# b. Ils ont mal aux pieds.
# c. Il vient te voir chaque jour.
# d. Il a reçu ta lettre.
# e. Les animaux ont soif. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. On commande une soupe.
# b. On a mal aux pieds.
# c. On vient te voir chaque jour.
# d. On a reçu ta lettre.
# e. Les animaux
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète les verbes avec les pronoms personnels je, tu, il ou ils.
# … récite • … font • … dit • … racontent • … finis • … va • … portent • … viennent • … prends • … voit • … discute • … fais • … veulent • … prépares • … grandis and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Complète les verbes avec les pronoms personnels je, tu, il ou ils.
# 1. J'... une chanson.
# 2. Tu... des devoirs.
# 3. Il... une lettre.
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète les phrases avec le verbe être conjugué au futur.
# a. Il … à l’heure.
# b. Je … heureux de voir ce film.
# c. Nous … plusieurs à prendre le bateau.
# d. Tu … toujours bienvenu chez nous.
# e. Elles … en vacances demain. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Il sera à l’heure.
# b. Je serai heureux de voir ce film.
# c. Nous serons plusieurs à prendre le bateau.
# d. Tu seras toujours
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète le texte suivant avec on ou ont.
# Certains objets que nous utilisons … été inventés pour des voyages dans l’espace.
# … a par exemple conçu les détecteurs de fumée pour une opération spatiale.
# Les bandes
# Velcro … maintenu les équipements en place dans l’espace.
# Ces objets … aujourd’hui une place dans la vie courante.
# Mon encyclopédie du ciel et de l’espace 6-9 ans, trad.
# Atelier Lauriot Prevost, © Éditions Gallimard Jeunesse. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Certains objets que nous utilisons quotidiennement … été inventés pour des voyages dans l'espace.
# Par exemple, les détecteurs de feu ont été conçus pour une opération spatiale
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie les phrases qui disent la même chose.
# a. Théo et Suzanne ont froid. ◆ Ils ont froid. ◆
# On a froid.
# b. Ils ont mangé tout le poulet. ◆ Il a mangé tout le poulet. ◆ Les convives ont mangé tout le poulet.
# c. On hésite entre la glace au chocolat et la glace à la vanille. ◆ Elle hésite entre la glace au chocolat et la glace à la vanille. ◆ Nous hésitons entre la glace au chocolat et la glace à la vanille. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Exercice de réécriture : Répétez les phrases suivantes en les simplifiant ou en changeant la personne.
# a. Jacques et Marie ont faim. ◆ Jacques a faim.
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie ces phrases et mets un accent grave sur les a soulignés quand c’est nécessaire.
# a. Je n’ai plus rien a lire.
# b. Ils attendent leurs amis a l’entrée du cinéma.
# c. Le match a mal commencé pour nous.
# d. Il a trouvé a manger dans le frigo.
# e. Ce n’est pas beau a voir. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# 1. Je n’ai plus rien à lire. (I don't have anything more to read.)
#    a. Je n’ai plus rien à lire.
#    b. I haven't got
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie ces phrases et conjugue les verbes entre parenthèses au futur.
# a. Maman (faire) une bonne purée et nous ( pouvoir) nous régaler au dîner .
# b. Je (venir) à l’entraînement mardi et j’(aller) à la compétition samedi.
# c. (Prendre)-vous le tramway ?
# Nous (voir).
# d. La voyante me (prédire) un avenir radieux.
# e. Il (vouloir) en savoir plus. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Mère (préparer) une délicieuse purée et nous (pouvons) nous délecter au dîner.
# b. Je (viendrai) à l'entra
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Réécris les groupes nominaux au féminin en utilisant le nom entre parenthèses.
# a. un écureuil curieux (souris)
# b. un superbe chalet neuf (maison)
# c. un ogre grincheux et boudeur (sorcière)
# d. un repas délicieux (glace) and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Exercice de réécriture : Remplacez les groupes nominaux au féminin en utilisant le nom entre parenthèses.
# a. un renard intrigant (écureuil
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Raconte ce qui se passe dans le dessin.
# a. Dresse une liste de verbes qui vont t’aider à décrire la course-poursuite.
# courir ◆ se faufiler ◆ …
# b. Décris la scène en quelques phrases et imagine comment elle se termine. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Liste de verbes pour décrire une course-poursuite :
# courir ◆ se faufiler ◆ s'enfuir ◆ se cacher ◆ bondir ◆ sauter
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète les pointillés avec des compléments.
# Il y a …, un bébé gorille est né …, sa maman prend soin de lui.
# Les soigneurs viennent le voir … .
# Il est très fragile.
# …, sa mère le transporte avec elle.
# Il fait la sieste … . and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Il y a cinq, une mère éléphante est née, son petit éléphant est avec elle, les vétérinaires viennent le voir, il est très fragile, elle le transporte
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète avec le pronom personnel qui convient.
# … écrivent ◆ … lisons ◆ … reliez ◆ … joue ◆ … comprends ◆ … peux ◆ … arrives ◆ … sont ◆ … chantes ◆ … ont ◆ … dit ◆ … reprend ◆ … donnes ◆ … fait and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# ... écrivent ◆... lisons ◆... reliions ◆... jouons ◆... comprenons ◆... pouvons ◆... arrivons ◆... sommes ◆... chantonn
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Recopie tous les verbes conjugués.
# a. Les étamines produisent du pollen.
# b. Le pistil contient des ovules.
# c. Le vent transporte le pollen.
# d. Après fécondation, les ovules se transforment en graines. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Les fleurs produisent du nectar.
# b. Les abeilles collectent le nectar.
# c. Le nectar attire les abeilles.
# d. Après fécond
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Classe les animaux dans le tableau.
# les oiseaux
# les insectes
# une hirondelle • une mouche • un aigle • un moustique • une coccinelle • une pie • un pingouin • un moineau • une guêpe • un papillon • une mésange • une sauterelle and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
#
# Les animaux aquatiques
# les poissons
# un poisson rouge • une tortue marine • un dauphin • une anguille • une crevette • un krill • une moule • une
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète ces phrases avec le nom du vent qui convient.
# bise ◆ brise ◆ bourrasque ◆ tornade
# a. La … souffle en hiver.
# b. La … a détruit de nombreux toits.
# c. Une légère … pousse le voilier au large.
# d. Une soudaine … a retourné mon parapluie ! and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# Complète ces phrases avec le nom du vent qui convient.
# bise ◆ brise ◆ bourrasque ◆ tornade
# a. Le vent … souffle doucement dans ma chambre.
# ----------------------------------------------------------------------------------------------------
# Prompt: Each text is an exercise extracted from school manual for elementary French student. Analyze the following text from Complète les phrases suivantes avec son ou sont.
# a. Ils … venus.
# b. Papa sort … gâteau du four.
# c. Où … les bougies ?
# d. … cadeau lui a plu.
# e. C’était … plus beau cadeau.
# f. Marine et Élias … contents. and summarize the key themes. Based on the information summarized, generate the similar exercises, in French, not English. They can contain french grammar, vocabulary, comprehension and so on. Remember to keep the same format.
#  Generated text:
# a. Ils sont venus.
# b. Papa sort un gâteau du four.
# c. Où sont les bougies?
# d. C'est un cadeau lui a plu.
# e. C'
# ----------------------------------------------------------------------------------------------------
